# %% [markdown]
# <a href="https://colab.research.google.com/github/Stuna-alice/Face_racog_Mitsumi_v1/blob/master/C_backend.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)

import os
import zipfile
from googleapiclient.discovery import build

# Set the working directory
working_directory = '/content/gdrive/MyDrive/Winforms_data/yolov5'
os.chdir(working_directory)

# Google Drive API setup
drive_service = build('drive', 'v3')
#  Google Drive folder ID
folder_id = '1P78-aXnjqXUv6rwJG6-r6zc3ZjuB5463'

# Function to get the latest uploaded ZIP file
def get_latest_zip_file(folder_id):
    results = drive_service.files().list(q=f"'{folder_id}' in parents", orderBy="createdTime desc", pageSize=1).execute()
    files = results.get('files', [])
    if files:
        return files[0]['name']
    else:
        return None


# Get the latest uploaded ZIP file
latest_zip_file = get_latest_zip_file(folder_id)

# Check if a ZIP file was found
if latest_zip_file:
    # Extract the base name of the zip file (excluding the extension)
    base_name = os.path.splitext(os.path.basename(latest_zip_file))[0]

    # Update the YAML file with the extracted base name
    yaml_content = f"""
    train: {working_directory}/dataset_extract/{base_name}/images/train/
    val: {working_directory}/dataset_extract/{base_name}/images/val/
    nc: 1
    names: ['{base_name}']
    """

    # Write the updated YAML content to a file
    yaml_file_path = f'{working_directory}/data/defaultYamlpath.yaml'
    with open(yaml_file_path, 'w') as yaml_file:
        yaml_file.write(yaml_content)

    # Create the destination folder if it doesn't exist
    extracted_folder_path = f'{working_directory}/dataset_extract'
    os.makedirs(extracted_folder_path, exist_ok=True)

    # Define the path to the zip file and the destination folder
    zip_file_path = f'{working_directory}/zipfiles/{latest_zip_file}'

    # Ensure the correct file extension is added
    if not zip_file_path.endswith('.zip'):
        zip_file_path += '.zip'

    # Extract the contents of the zip file
    with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
        zip_ref.extractall(extracted_folder_path)

    print(f" '{latest_zip_file}' extracted to '{extracted_folder_path}'.")

    # Read user parameters from the text file
    text_file_path = f'{working_directory}/zipfiles/{base_name}.txt'
    if not os.path.exists(text_file_path):
        print(f"Error: Text file '{base_name}.txt' not found.")
    else:
        parameters = read_parameters(text_file_path)

        # Check if required parameters are present
        required_params = ['img', 'batch', 'epochs', 'weights']
        missing_params = [param for param in required_params if param not in parameters]

        if missing_params:
            print(f"Error: Missing parameters in text file: {', '.join(missing_params)}")
        else:
            # Train YOLOv5s with user parameters
            # train_command = f"!python train.py --img {parameters['img']} --batch {parameters['batch']} --epochs {parameters['epochs']} \n --data {yaml_file_path} --weights {parameters['weights']} --cache \n"

            # !python train.py --img {parameters['img']}  --batch {parameters['batch']} --epochs {parameters['epochs']} --data {yaml_file_path} --weights {parameters['weights']} --cache
            print('okies download')
else:
    print("No ZIP file found in the specified folder.")
# Out:
# Mounted at /content/gdrive
#  'chickenDB.zip' extracted to '/content/gdrive/MyDrive/Winforms_data/yolov5/dataset_extract'.
# train: weights=yolov5s.pt, cfg=, data=/content/gdrive/MyDrive/Winforms_data/yolov5/data/defaultYamlpath.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=2, batch_size=2, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: ⚠️ YOLOv5 is out of date by 8 commits. Use 'git pull' or 'git clone https://github.com/ultralytics/yolov5' to update.
# YOLOv5 🚀 v7.0-241-gb6a65e1 Python-3.10.12 torch-2.1.0+cu118 CPU
#
# hyperparameters: lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0
# Comet: run 'pip install comet_ml' to automatically track and visualize YOLOv5 🚀 runs in Comet
# TensorBoard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# Overriding model.yaml nc=80 with nc=1
#
#                  from  n    params  module                                  arguments
#   0                -1  1      3520  models.common.Conv                      [3, 32, 6, 2, 2]
#   1                -1  1     18560  models.common.Conv                      [32, 64, 3, 2]
#   2                -1  1     18816  models.common.C3                        [64, 64, 1]
#   3                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   4                -1  2    115712  models.common.C3                        [128, 128, 2]
#   5                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
#   6                -1  3    625152  models.common.C3                        [256, 256, 3]
#   7                -1  1   1180672  models.common.Conv                      [256, 512, 3, 2]
#   8                -1  1   1182720  models.common.C3                        [512, 512, 1]
#   9                -1  1    656896  models.common.SPPF                      [512, 512, 5]
#  10                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  1    361984  models.common.C3                        [512, 256, 1, False]
#  14                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  1     90880  models.common.C3                        [256, 128, 1, False]
#  18                -1  1    147712  models.common.Conv                      [128, 128, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  1    296448  models.common.C3                        [256, 256, 1, False]
#  21                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  1   1182720  models.common.C3                        [512, 512, 1, False]
#  24      [17, 20, 23]  1     16182  models.yolo.Detect                      [1, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [128, 256, 512]]
# Model summary: 214 layers, 7022326 parameters, 7022326 gradients, 15.9 GFLOPs
#
# Transferred 343/349 items from yolov5s.pt
# optimizer: SGD(lr=0.01) with parameter groups 57 weight(decay=0.0), 60 weight(decay=0.0005), 60 bias
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# train: Scanning /content/gdrive/MyDrive/Winforms_data/yolov5/dataset_extract/chickenDB/labels/train... 46 images, 0 backgrounds, 0 corrupt: 100% 46/46 [00:00<00:00, 124.44it/s]
# train: New cache created: /content/gdrive/MyDrive/Winforms_data/yolov5/dataset_extract/chickenDB/labels/train.cache
# train: Caching images (0.0GB ram): 100% 46/46 [00:00<00:00, 58.34it/s]
# val: Scanning /content/gdrive/MyDrive/Winforms_data/yolov5/dataset_extract/chickenDB/labels/val... 28 images, 0 backgrounds, 0 corrupt: 100% 28/28 [00:00<00:00, 45.05it/s]
# val: New cache created: /content/gdrive/MyDrive/Winforms_data/yolov5/dataset_extract/chickenDB/labels/val.cache
# val: Caching images (0.0GB ram): 100% 28/28 [00:01<00:00, 24.55it/s]
#
# AutoAnchor: 3.12 anchors/target, 1.000 Best Possible Recall (BPR). Current anchors are a good fit to dataset ✅
# Plotting labels to runs/train/exp57/labels.jpg...
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to runs/train/exp57
# Starting training for 2 epochs...
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#         0/1         0G    0.08698    0.03694          0          7        640: 100% 23/23 [01:25<00:00,  3.70s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:   0% 0/7 [00:00<?, ?it/s]WARNING ⚠️ NMS time limit 0.700s exceeded
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:  14% 1/7 [00:02<00:13,  2.20s/it]WARNING ⚠️ NMS time limit 0.700s exceeded
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:  29% 2/7 [00:04<00:10,  2.18s/it]WARNING ⚠️ NMS time limit 0.700s exceeded
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:  43% 3/7 [00:06<00:09,  2.29s/it]WARNING ⚠️ NMS time limit 0.700s exceeded
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:  57% 4/7 [00:10<00:08,  2.70s/it]WARNING ⚠️ NMS time limit 0.700s exceeded
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:  71% 5/7 [00:14<00:06,  3.29s/it]WARNING ⚠️ NMS time limit 0.700s exceeded
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:  86% 6/7 [00:17<00:03,  3.24s/it]WARNING ⚠️ NMS time limit 0.700s exceeded
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 7/7 [00:21<00:00,  3.07s/it]
#                    all         28         43    0.00359      0.326    0.00315   0.000787
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#         1/1         0G    0.09798    0.03391          0          5        640:  30% 7/23 [00:23<00:49,  3.09s/it]

# %%
from google.colab import drive
drive.mount('/content/gdrive')

# Change directory to allow Google to access GDrive
# %cd /content/gdrive/MyDrive/Winforms_data

# Clone YOLOv5 repository
# !git clone https://github.com/ultralytics/yolov5

# Change directory to the YOLOv5 repository
# %cd yolov5

# Install required packages
# %pip install -qr requirements.txt comet_ml

import torch
import utils
display = utils.notebook_init()  # checks
import zipfile
import os


# Define the path to the zip file and the destination folder
zipFile_name = 'chickenDB.zip'
zip_file_path = '/content/gdrive/MyDrive/Winforms_data/yolov5/zipfiles/' + zipFile_name
extracted_folder_path = '/content/gdrive/MyDrive/Winforms_data/yolov5/dataset_extract'

# Create the destination folder if it doesn't exist
os.makedirs(extracted_folder_path, exist_ok=True)

# Extract the contents of the zip file
with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
    zip_ref.extractall(extracted_folder_path)

print(f" '{zipFile_name}' extracted to '{extracted_folder_path}'.")


# make label code
#training
# Train YOLOv5s on marmot for 3 epochs
# !python train.py --img 640  --batch 20 --epochs 10 --data controlDB.yaml --weights yolov5s.pt --cache

# %%
from google.colab import drive
drive.mount('/content/gdrive')

# Change directory to allow Google to access GDrive
# %cd /content/gdrive/MyDrive/Winforms_data

# Clone YOLOv5 repository
# !git clone https://github.com/ultralytics/yolov5

# Change directory to the YOLOv5 repository
# %cd yolov5

# Install required packages
# %pip install -qr requirements.txt comet_ml

import torch
import utils
display = utils.notebook_init()  # checks
import zipfile
import os

# Define the zip file name
zip_file_name = 'chickenDB.zip'  # Change this to the actual zip file name

# Extract the base name of the zip file (excluding the extension)
base_name = os.path.splitext(os.path.basename(zip_file_name))[0]

# Update the YAML file with the extracted base name
yaml_content = f"""
train: /content/gdrive/MyDrive/Winforms_data/yolov5/dataset_extract/{base_name}/images/train/
val: /content/gdrive/MyDrive/Winforms_data/yolov5/dataset_extract/{base_name}/images/val/
nc: 1
names: ['{base_name}']
"""

# Write the updated YAML content to a file
yaml_file_path = '/content/gdrive/MyDrive/Winforms_data/yolov5/data/defaultYamlpath.yaml'
with open(yaml_file_path, 'w') as yaml_file:
    yaml_file.write(yaml_content)

# Create the destination folder if it doesn't exist
extracted_folder_path = f'/content/gdrive/MyDrive/Winforms_data/yolov5/dataset_extract'
os.makedirs(extracted_folder_path, exist_ok=True)

# Define the path to the zip file and the destination folder
zip_file_path = f'/content/gdrive/MyDrive/Winforms_data/yolov5/zipfiles/{zip_file_name}'

# Extract the contents of the zip file
with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
    zip_ref.extractall(extracted_folder_path)

print(f" '{zip_file_name}' extracted to '{extracted_folder_path}'.")

# Make label code
# training
# Train YOLOv5s on marmot for 3 epochs
# !python train.py --img 640 --batch 2 --epochs 2 --data {yaml_file_path} --weights yolov5s.pt --cache

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)

import os
import zipfile

# Set the working directory
working_directory = '/content/gdrive/MyDrive/Winforms_data/yolov5'
os.chdir(working_directory)

# Function to read parameters from the text file
def read_parameters(file_path):
    parameters = {}
    with open(file_path, 'r') as file:
        lines = file.readlines()
        for line in lines:
            key, value = line.strip().split(':')
            parameters[key.strip()] = value.strip()
    return parameters

# Define the zip file name
zip_file_name = 'chickenDB.zip'

# Extract the base name of the zip file (excluding the extension)
base_name = os.path.splitext(os.path.basename(zip_file_name))[0]

# Update the YAML file with the extracted base name
yaml_content = f"""
train: {working_directory}/dataset_extract/{base_name}/images/train/
val: {working_directory}/dataset_extract/{base_name}/images/val/
nc: 1
names: ['{base_name}']
"""

# Write the updated YAML content to a file
yaml_file_path = f'{working_directory}/data/defaultYamlpath.yaml'
with open(yaml_file_path, 'w') as yaml_file:
    yaml_file.write(yaml_content)

# Create the destination folder if it doesn't exist
extracted_folder_path = f'{working_directory}/dataset_extract'
os.makedirs(extracted_folder_path, exist_ok=True)

# Define the path to the zip file and the destination folder
zip_file_path = f'{working_directory}/zipfiles/{zip_file_name}'

# Extract the contents of the zip file
with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
    zip_ref.extractall(extracted_folder_path)

print(f" '{zip_file_name}' extracted to '{extracted_folder_path}'.")

# Read user parameters from the text file
text_file_path = f'{working_directory}/zipfiles/{base_name}.txt'
if not os.path.exists(text_file_path):
    print(f"Error: Text file '{base_name}.txt' not found.")
else:
    parameters = read_parameters(text_file_path)

    # Check if required parameters are present
    required_params = ['img', 'batch', 'epochs', 'weights']
    missing_params = [param for param in required_params if param not in parameters]

    if missing_params:
        print(f"Error: Missing parameters in text file: {', '.join(missing_params)}")
    else:

        # Train YOLOv5s with user parameters
        #train_command = f"!python train.py --img {parameters['img']} --batch {parameters['batch']} --epochs {parameters['epochs']} \n --data {yaml_file_path} --weights {parameters['weights']} --cache \n"

        # !python train.py --img {parameters['img']}  --batch {parameters['batch']} --epochs {parameters['epochs']} --data {yaml_file_path} --weights {parameters['weights']} --cache

       # print(f"Training command: {train_command}")

        # Debugging: Print the current working directory
       # print("Current working directory:", os.getcwd())

        # Debug
        #print("Training command:", train_command)

        # Run
        #os.system(train_command)
# Out:
# Mounted at /content/gdrive
#  'chickenDB.zip' extracted to '/content/gdrive/MyDrive/Winforms_data/yolov5/dataset_extract'.
# train: weights=yolov5s.pt, cfg=, data=/content/gdrive/MyDrive/Winforms_data/yolov5/data/defaultYamlpath.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=2, batch_size=2, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: ⚠️ YOLOv5 is out of date by 8 commits. Use 'git pull' or 'git clone https://github.com/ultralytics/yolov5' to update.
# YOLOv5 🚀 v7.0-241-gb6a65e1 Python-3.10.12 torch-2.1.0+cu118 CPU
#
# hyperparameters: lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0
# Comet: run 'pip install comet_ml' to automatically track and visualize YOLOv5 🚀 runs in Comet
# TensorBoard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# Overriding model.yaml nc=80 with nc=1
#
#                  from  n    params  module                                  arguments
#   0                -1  1      3520  models.common.Conv                      [3, 32, 6, 2, 2]
#   1                -1  1     18560  models.common.Conv                      [32, 64, 3, 2]
#   2                -1  1     18816  models.common.C3                        [64, 64, 1]
#   3                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   4                -1  2    115712  models.common.C3                        [128, 128, 2]
#   5                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
#   6                -1  3    625152  models.common.C3                        [256, 256, 3]
#   7                -1  1   1180672  models.common.Conv                      [256, 512, 3, 2]
#   8                -1  1   1182720  models.common.C3                        [512, 512, 1]
#   9                -1  1    656896  models.common.SPPF                      [512, 512, 5]
#  10                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  1    361984  models.common.C3                        [512, 256, 1, False]
#  14                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  1     90880  models.common.C3                        [256, 128, 1, False]
#  18                -1  1    147712  models.common.Conv                      [128, 128, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  1    296448  models.common.C3                        [256, 256, 1, False]
#  21                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  1   1182720  models.common.C3                        [512, 512, 1, False]
#  24      [17, 20, 23]  1     16182  models.yolo.Detect                      [1, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [128, 256, 512]]
# Model summary: 214 layers, 7022326 parameters, 7022326 gradients, 15.9 GFLOPs
#
# Transferred 343/349 items from yolov5s.pt
# optimizer: SGD(lr=0.01) with parameter groups 57 weight(decay=0.0), 60 weight(decay=0.0005), 60 bias
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# train: Scanning /content/gdrive/MyDrive/Winforms_data/yolov5/dataset_extract/chickenDB/labels/train.cache... 0 images, 0 backgrounds, 46 corrupt: 100% 46/46 [00:00<?, ?it/s]
# train: WARNING ⚠️ /content/gdrive/MyDrive/Winforms_data/yolov5/dataset_extract/chickenDB/images/train/01I4JR8PX3B8.jpg: ignoring corrupt image/label: cannot identify image file '/content/gdrive/MyDrive/Winforms_data/yolov5/dataset_extract/chickenDB/images/train/01I4JR8PX3B8.jpg'
# train: WARNING ⚠️ /content/gdrive/MyDrive/Winforms_data/yolov5/dataset_extract/chickenDB/images/train/08OZ5SPN1U9F.jpg: ignoring corrupt image/label: cannot identify image file '/content/gdrive/MyDrive/Winforms_data/yolov5/dataset_extract/chickenDB/images/train/08OZ5SPN1U9F.jpg'
# train: WARNING ⚠️ /content/gdrive/MyDrive/Winforms_data/yolov5/dataset_extract/chickenDB/images/train/0K3D5SDTO0RJ.jpg: ignoring corrupt image/label: cannot identify image file '/content/gdrive/MyDrive/Winforms_data/yolov5/dataset_extract/chickenDB/images/train/0K3D5SDTO0RJ.jpg'
# train: WARNING ⚠️ /content/gdrive/MyDrive/Winforms_data/yolov5/dataset_extract/chickenDB/images/train/0L6FFWDX5V3P.jpg: ignoring corrupt image/label: cannot identify image file '/content/gdrive/MyDrive/Winforms_data/yolov5/dataset_extract/chickenDB/images/train/0L6FFWDX5V3P.jpg'
# train: WARNING ⚠️ /content/gdrive/MyDrive/Winforms_data/yolov5/dataset_extract/chickenDB/images/train/0RFTU3N71UAF.jpg: ignoring corrupt image/label: cannot identify image file '/content/gdrive/MyDrive/Winforms_data/yolov5/dataset_extract/chickenDB/images/train/0RFTU3N71UAF.jpg'
# train: WARNING ⚠️ /content/gdrive/MyDrive/Winforms_data/yolov5/dataset_extract/chickenDB/images/train/0T2BXNBHXLTU.jpg: ignoring corrupt image/label: cannot identify image file '/content/gdrive/MyDrive/Winforms_data/yolov5/dataset_extract/chickenDB/images/train/0T2BXNBHXLTU.jpg'
# train: WARNING ⚠️ /content/gdrive/MyDrive/Winforms_data/yolov5/dataset_extract/chickenDB/images/train/0U5DJ4AHL7U8.jpg: ignoring corrupt image/label: cannot identify image file '/content/gdrive/MyDrive/Winforms_data/yolov5/dataset_extract/chickenDB/images/train/0U5DJ4AHL7U8.jpg'
# train: WARNING ⚠️ /content/gdrive/MyDrive/Winforms_data/yolov5/dataset_extract/chickenDB/images/train/0VIQXR823YYN.jpg: ignoring corrupt image/label: cannot identify image file '/content/gdrive/MyDrive/Winforms_data/yolov5/dataset_extract/chickenDB/images/train/0VIQXR823YYN.jpg'
# train: WARNING ⚠️ /content/gdrive/MyDrive/Winforms_data/yolov5/dataset_extract/chickenDB/images/train/1AA9DBQE512G.jpg: ignoring corrupt image/label: cannot identify image file '/content/gdrive/MyDrive/Winforms_data/yolov5/dataset_extract/chickenDB/images/train/1AA9DBQE512G.jpg'
# train: WARNING ⚠️ /content/gdrive/MyDrive/Winforms_data/yolov5/dataset_extract/chickenDB/images/train/1BD9DQ8ZT4UR.jpg: ignoring corrupt image/label: cannot identify image file '/content/gdrive/MyDrive/Winforms_data/yolov5/dataset_extract/chickenDB/images/train/1BD9DQ8ZT4UR.jpg'
# train: WARNING ⚠️ /content/gdrive/MyDrive/Winforms_data/yolov5/dataset_extract/chickenDB/images/train/1LRILIIFI626.jpg: ignoring corrupt image/label: cannot identify image file '/content/gdrive/MyDrive/Winforms_data/yolov5/dataset_extract/chickenDB/images/train/1LRILIIFI626.jpg'
# train: WARNING ⚠️ /content/gdrive/MyDrive/Winforms_data/yolov5/dataset_extract/chickenDB/images/train/1O9LZD4GDLEG.jpg: ignoring corrupt image/label: cannot identify image file '/content/gdrive/MyDrive/Winforms_data/yolov5/dataset_extract/chickenDB/images/train/1O9LZD4GDLEG.jpg'
# train: WARNING ⚠️ /content/gdrive/MyDrive/Winforms_data/yolov5/dataset_extract/chickenDB/images/train/1OX6JD87ZL6M.jpg: ignoring corrupt image/label: cannot identify image file '/content/gdrive/MyDrive/Winforms_data/yolov5/dataset_extract/chickenDB/images/train/1OX6JD87ZL6M.jpg'
# train: WARNING ⚠️ /content/gdrive/MyDrive/Winforms_data/yolov5/dataset_extract/chickenDB/images/train/1P39IIAJ8T7S.jpg: ignoring corrupt image/label: cannot identify image file '/content/gdrive/MyDrive/Winforms_data/yolov5/dataset_extract/chickenDB/images/train/1P39IIAJ8T7S.jpg'
# train: WARNING ⚠️ /content/gdrive/MyDrive/Winforms_data/yolov5/dataset_extract/chickenDB/images/train/1WHCYYP4QBBB.jpg: ignoring corrupt image/label: cannot identify image file '/content/gdrive/MyDrive/Winforms_data/yolov5/dataset_extract/chickenDB/images/train/1WHCYYP4QBBB.jpg'
# train: WARNING ⚠️ /content/gdrive/MyDrive/Winforms_data/yolov5/dataset_extract/chickenDB/images/train/1ZLB7IELNMCD.jpg: ignoring corrupt image/label: cannot identify image file '/content/gdrive/MyDrive/Winforms_data/yolov5/dataset_extract/chickenDB/images/train/1ZLB7IELNMCD.jpg'
# train: WARNING ⚠️ /content/gdrive/MyDrive/Winforms_data/yolov5/dataset_extract/chickenDB/images/train/2KGBBY1M31AE.jpg: ignoring corrupt image/label: cannot identify image file '/content/gdrive/MyDrive/Winforms_data/yolov5/dataset_extract/chickenDB/images/train/2KGBBY1M31AE.jpg'
# train: WARNING ⚠️ /content/gdrive/MyDrive/Winforms_data/yolov5/dataset_extract/chickenDB/images/train/2KTMQDH6RR20.jpg: ignoring corrupt image/label: cannot identify image file '/content/gdrive/MyDrive/Winforms_data/yolov5/dataset_extract/chickenDB/images/train/2KTMQDH6RR20.jpg'
# train: WARNING ⚠️ /content/gdrive/MyDrive/Winforms_data/yolov5/dataset_extract/chickenDB/images/train/2TNRWXSD6MSM.jpg: ignoring corrupt image/label: cannot identify image file '/content/gdrive/MyDrive/Winforms_data/yolov5/dataset_extract/chickenDB/images/train/2TNRWXSD6MSM.jpg'
# train: WARNING ⚠️ /content/gdrive/MyDrive/Winforms_data/yolov5/dataset_extract/chickenDB/images/train/3IWTRGX47VBW.jpg: ignoring corrupt image/label: cannot identify image file '/content/gdrive/MyDrive/Winforms_data/yolov5/dataset_extract/chickenDB/images/train/3IWTRGX47VBW.jpg'
# train: WARNING ⚠️ /content/gdrive/MyDrive/Winforms_data/yolov5/dataset_extract/chickenDB/images/train/3LMOHKHBDS3X.jpg: ignoring corrupt image/label: cannot identify image file '/content/gdrive/MyDrive/Winforms_data/yolov5/dataset_extract/chickenDB/images/train/3LMOHKHBDS3X.jpg'
# train: WARNING ⚠️ /content/gdrive/MyDrive/Winforms_data/yolov5/dataset_extract/chickenDB/images/train/4I7DWG9W73OK.jpg: ignoring corrupt image/label: cannot identify image file '/content/gdrive/MyDrive/Winforms_data/yolov5/dataset_extract/chickenDB/images/train/4I7DWG9W73OK.jpg'
# train: WARNING ⚠️ /content/gdrive/MyDrive/Winforms_data/yolov5/dataset_extract/chickenDB/images/train/4JRCLNO1L7QO.jpg: ignoring corrupt image/label: cannot identify image file '/content/gdrive/MyDrive/Winforms_data/yolov5/dataset_extract/chickenDB/images/train/4JRCLNO1L7QO.jpg'
# train: WARNING ⚠️ /content/gdrive/MyDrive/Winforms_data/yolov5/dataset_extract/chickenDB/images/train/4T82PAI1HM8G.jpg: ignoring corrupt image/label: cannot identify image file '/content/gdrive/MyDrive/Winforms_data/yolov5/dataset_extract/chickenDB/images/train/4T82PAI1HM8G.jpg'
# train: WARNING ⚠️ /content/gdrive/MyDrive/Winforms_data/yolov5/dataset_extract/chickenDB/images/train/4TKATE45G035.jpg: ignoring corrupt image/label: cannot identify image file '/content/gdrive/MyDrive/Winforms_data/yolov5/dataset_extract/chickenDB/images/train/4TKATE45G035.jpg'
# train: WARNING ⚠️ /content/gdrive/MyDrive/Winforms_data/yolov5/dataset_extract/chickenDB/images/train/5B63558LQ3R7.jpg: ignoring corrupt image/label: cannot identify image file '/content/gdrive/MyDrive/Winforms_data/yolov5/dataset_extract/chickenDB/images/train/5B63558LQ3R7.jpg'
# train: WARNING ⚠️ /content/gdrive/MyDrive/Winforms_data/yolov5/dataset_extract/chickenDB/images/train/5LSD4L13X6EJ.jpg: ignoring corrupt image/label: cannot identify image file '/content/gdrive/MyDrive/Winforms_data/yolov5/dataset_extract/chickenDB/images/train/5LSD4L13X6EJ.jpg'
# train: WARNING ⚠️ /content/gdrive/MyDrive/Winforms_data/yolov5/dataset_extract/chickenDB/images/train/5OU4181SP6BZ.jpg: ignoring corrupt image/label: cannot identify image file '/content/gdrive/MyDrive/Winforms_data/yolov5/dataset_extract/chickenDB/images/train/5OU4181SP6BZ.jpg'
# train: WARNING ⚠️ /content/gdrive/MyDrive/Winforms_data/yolov5/dataset_extract/chickenDB/images/train/5QGOZ68RTPD5.jpg: ignoring corrupt image/label: cannot identify image file '/content/gdrive/MyDrive/Winforms_data/yolov5/dataset_extract/chickenDB/images/train/5QGOZ68RTPD5.jpg'
# train: WARNING ⚠️ /content/gdrive/MyDrive/Winforms_data/yolov5/dataset_extract/chickenDB/images/train/5S2Z8N8RHE3T.jpg: ignoring corrupt image/label: cannot identify image file '/content/gdrive/MyDrive/Winforms_data/yolov5/dataset_extract/chickenDB/images/train/5S2Z8N8RHE3T.jpg'
# train: WARNING ⚠️ /content/gdrive/MyDrive/Winforms_data/yolov5/dataset_extract/chickenDB/images/train/5VRZASYRK9MR.jpg: ignoring corrupt image/label: cannot identify image file '/content/gdrive/MyDrive/Winforms_data/yolov5/dataset_extract/chickenDB/images/train/5VRZASYRK9MR.jpg'
# train: WARNING ⚠️ /content/gdrive/MyDrive/Winforms_data/yolov5/dataset_extract/chickenDB/images/train/5XBUTCJDUIGH.jpg: ignoring corrupt image/label: cannot identify image file '/content/gdrive/MyDrive/Winforms_data/yolov5/dataset_extract/chickenDB/images/train/5XBUTCJDUIGH.jpg'
# train: WARNING ⚠️ /content/gdrive/MyDrive/Winforms_data/yolov5/dataset_extract/chickenDB/images/train/6G2QA4GBKIDX.jpg: ignoring corrupt image/label: cannot identify image file '/content/gdrive/MyDrive/Winforms_data/yolov5/dataset_extract/chickenDB/images/train/6G2QA4GBKIDX.jpg'
# train: WARNING ⚠️ /content/gdrive/MyDrive/Winforms_data/yolov5/dataset_extract/chickenDB/images/train/6LP5PUXH0T0G.jpg: ignoring corrupt image/label: cannot identify image file '/content/gdrive/MyDrive/Winforms_data/yolov5/dataset_extract/chickenDB/images/train/6LP5PUXH0T0G.jpg'
# train: WARNING ⚠️ /content/gdrive/MyDrive/Winforms_data/yolov5/dataset_extract/chickenDB/images/train/6Q16NMCZX1GA.jpg: ignoring corrupt image/label: cannot identify image file '/content/gdrive/MyDrive/Winforms_data/yolov5/dataset_extract/chickenDB/images/train/6Q16NMCZX1GA.jpg'
# train: WARNING ⚠️ /content/gdrive/MyDrive/Winforms_data/yolov5/dataset_extract/chickenDB/images/train/6RURO8IGWJX4.jpg: ignoring corrupt image/label: cannot identify image file '/content/gdrive/MyDrive/Winforms_data/yolov5/dataset_extract/chickenDB/images/train/6RURO8IGWJX4.jpg'
# train: WARNING ⚠️ /content/gdrive/MyDrive/Winforms_data/yolov5/dataset_extract/chickenDB/images/train/6X0CW0A8JSSJ.jpg: ignoring corrupt image/label: cannot identify image file '/content/gdrive/MyDrive/Winforms_data/yolov5/dataset_extract/chickenDB/images/train/6X0CW0A8JSSJ.jpg'
# train: WARNING ⚠️ /content/gdrive/MyDrive/Winforms_data/yolov5/dataset_extract/chickenDB/images/train/7BO7XC21FY83.jpg: ignoring corrupt image/label: cannot identify image file '/content/gdrive/MyDrive/Winforms_data/yolov5/dataset_extract/chickenDB/images/train/7BO7XC21FY83.jpg'
# train: WARNING ⚠️ /content/gdrive/MyDrive/Winforms_data/yolov5/dataset_extract/chickenDB/images/train/7G5EDQI7BD15.jpg: ignoring corrupt image/label: cannot identify image file '/content/gdrive/MyDrive/Winforms_data/yolov5/dataset_extract/chickenDB/images/train/7G5EDQI7BD15.jpg'
# train: WARNING ⚠️ /content/gdrive/MyDrive/Winforms_data/yolov5/dataset_extract/chickenDB/images/train/7GCERLOLNV6B.jpg: ignoring corrupt image/label: cannot identify image file '/content/gdrive/MyDrive/Winforms_data/yolov5/dataset_extract/chickenDB/images/train/7GCERLOLNV6B.jpg'
# train: WARNING ⚠️ /content/gdrive/MyDrive/Winforms_data/yolov5/dataset_extract/chickenDB/images/train/7GFD1CLV4A7K.jpg: ignoring corrupt image/label: cannot identify image file '/content/gdrive/MyDrive/Winforms_data/yolov5/dataset_extract/chickenDB/images/train/7GFD1CLV4A7K.jpg'
# train: WARNING ⚠️ /content/gdrive/MyDrive/Winforms_data/yolov5/dataset_extract/chickenDB/images/train/7IA0ZH8WJAJW.jpg: ignoring corrupt image/label: cannot identify image file '/content/gdrive/MyDrive/Winforms_data/yolov5/dataset_extract/chickenDB/images/train/7IA0ZH8WJAJW.jpg'
# train: WARNING ⚠️ /content/gdrive/MyDrive/Winforms_data/yolov5/dataset_extract/chickenDB/images/train/7IH9GVIEJYR2.jpg: ignoring corrupt image/label: cannot identify image file '/content/gdrive/MyDrive/Winforms_data/yolov5/dataset_extract/chickenDB/images/train/7IH9GVIEJYR2.jpg'
# train: WARNING ⚠️ /content/gdrive/MyDrive/Winforms_data/yolov5/dataset_extract/chickenDB/images/train/7K9BZL76YKRC.jpg: ignoring corrupt image/label: cannot identify image file '/content/gdrive/MyDrive/Winforms_data/yolov5/dataset_extract/chickenDB/images/train/7K9BZL76YKRC.jpg'
# train: WARNING ⚠️ /content/gdrive/MyDrive/Winforms_data/yolov5/dataset_extract/chickenDB/images/train/8F3IH0F6AV6J.jpg: ignoring corrupt image/label: cannot identify image file '/content/gdrive/MyDrive/Winforms_data/yolov5/dataset_extract/chickenDB/images/train/8F3IH0F6AV6J.jpg'
# train: WARNING ⚠️ /content/gdrive/MyDrive/Winforms_data/yolov5/dataset_extract/chickenDB/images/train/9PJFZ8XSPDFZ.jpg: ignoring corrupt image/label: cannot identify image file '/content/gdrive/MyDrive/Winforms_data/yolov5/dataset_extract/chickenDB/images/train/9PJFZ8XSPDFZ.jpg'
# Traceback (most recent call last):
#   File "/content/gdrive/MyDrive/Winforms_data/yolov5/train.py", line 647, in <module>
#     main(opt)
#   File "/content/gdrive/MyDrive/Winforms_data/yolov5/train.py", line 536, in main
#     train(opt.hyp, opt, device, callbacks)
#   File "/content/gdrive/MyDrive/Winforms_data/yolov5/train.py", line 195, in train
#     train_loader, dataset = create_dataloader(train_path,
#   File "/content/gdrive/MyDrive/Winforms_data/yolov5/utils/dataloaders.py", line 124, in create_dataloader
#     dataset = LoadImagesAndLabels(
#   File "/content/gdrive/MyDrive/Winforms_data/yolov5/utils/dataloaders.py", line 502, in __init__
#     assert nf > 0 or not augment, f'{prefix}No labels found in {cache_path}, can not start training. {HELP_URL}'
# AssertionError: train: No labels found in /content/gdrive/MyDrive/Winforms_data/yolov5/dataset_extract/chickenDB/labels/train.cache, can not start training. See https://docs.ultralytics.com/yolov5/tutorials/train_custom_data
